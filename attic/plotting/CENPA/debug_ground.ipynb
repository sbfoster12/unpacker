# %%
from nearline_helpers import *
# %jsroot on
# Out:
# Welcome to JupyROOT 6.26/10

# %%
infile = '../bin/./run00372_00000.mid.root'
f = r.TFile(infile)
t = f.Get("tree")

# %%
t.Print()
# Out:
# ******************************************************************************
# *Tree    :tree      : tree                                                   *
# *Entries :       78 : Total =         2357532 bytes  File  Size =     115006 *
# *        :          : Tree compression factor =  24.21                       *
# ******************************************************************************
# *Br    0 :waveforms_raw : Int_t waveforms_raw_                               *
# *Entries :       78 : Total  Size=      13054 bytes  File Size  =        429 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.66     *
# *............................................................................*
# *Br    1 :waveforms_raw.fUniqueID : UInt_t fUniqueID[waveforms_raw_]         *
# *Entries :       78 : Total  Size=       2607 bytes  File Size  =       1942 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.00     *
# ...

# %%
for i, e in enumerate(t):
    for wf in e.waveforms_corr:
        plot_waveform(wf)
        plt.show()

    if(i > -1):
        break
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
