# %%
from nearline_helpers import *
# %jsroot on
# Out:
# Welcome to JupyROOT 6.26/10

# %%
runs = [437]
t = r.TChain("tree")
for run in runs:
    t.Add(f"../bin/*{run}*root")
t.GetEntries()
# Out:
# 50370

# %%
c = r.TCanvas()
t.Draw("waveforms_corr.amcNum:waveforms_corr.channelTag","","colz text")
c.Draw()
# Out:
# <div id="root_plot_1700045118128"
#      style="width: 696px; height: 472px">
# </div>
# <script>
#
# function display_root_plot_1700045118128(Core) {
# ...

# %%
c = r.TCanvas()
t.Draw("lyso_waveforms.amcNum:lyso_waveforms.channelTag","","colz text")
c.Draw()
# Out:
# <div id="root_plot_1700045118489"
#      style="width: 696px; height: 472px">
# </div>
# <script>
#
# function display_root_plot_1700045118489(Core) {
# ...

# %%
t.GetEntry(0)
# Out:
# 105103

# %%
t.nai_waveforms.size()
# Out:
# 4

# %%
t.nai_integrals[0].raw.GetObject()

# %%
t.lyso_waveforms.size()
# Out:
# 10

# %%
for wfi in t.lyso_waveforms:
        if(wfi.amcNum != 1):
            continue
        amc = wfi.amcNum
        channel = wfi.channelTag
        print(wfi,amc,channel)
# Out:
# Name: dataProducts::Waveform Title:  1 0
# Name: dataProducts::Waveform Title:  1 1
# Name: dataProducts::Waveform Title:  1 2
# Name: dataProducts::Waveform Title:  1 3
# Name: dataProducts::Waveform Title:  1 4

# %%
plot_event_wf(t.lyso_waveforms)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...

# %%
counter = 0
for i, e in enumerate(t):
    for wfi in e.nai_integrals:
        
        plot_integral(wfi)
        plt.show()
        counter +=1
    if counter > 5:
        break

# %%
wfi.raw.GetObject()

# %%
c = r.TCanvas()
t.Draw("nai_integrals.integral>>h(200,0,100000)","nai_integrals.channelTag == 0","")
c.Draw()
